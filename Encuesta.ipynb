# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_excel(r"C:\Users\asus\OneDrive\Documentos\GitHub\UFO_App_Streamlit_Proyecto\Respuestas_encuesta_Ovni.xlsx")

# %%
df
# Out:
#            Marca temporal ¿Cómo te llamas?  \
# 0 2023-11-29 11:15:50.378           Andrés
# 1 2023-11-29 11:16:33.172              NaN
# 2 2023-11-29 11:17:26.194            Erika
# 3 2023-11-29 11:19:15.860           Carlos
# 4 2023-11-29 11:23:53.363           Joseba
# 5 2023-11-29 11:37:24.222         Demetrio
#
#   Pregunta 1: ¿Crees que realmente existen los OVNIs?  \
# 0                                                 Sí
# 1                                                 Sí
# 2                                                 Sí
# 3                                                 Sí
# 4                                                 Sí
# 5                                                 Sí
#
#   Pregunta 2: Si fueras un OVNI, ¿de qué tipo serías?  \
# 0                                               Otro
# 1                                      Bola de fuego
# 2                                      Bola de fuego
# 3                                      Bola de fuego
# ...

# %%
df['Marca temporal'] = pd.to_datetime(df['Marca temporal'])  # Convierte la columna de tiempo a formato datetime

# %%
# Gráfico de pastel (pie) para la Pregunta 1
plt.style.use('dark_background')
plt.figure(figsize=(10, 6))
df['Pregunta 1: ¿Crees que realmente existen los OVNIs?'].value_counts().plot.pie(autopct='%1.1f%%', colors=sns.color_palette('viridis'))
plt.title('Creencia en la Existencia de OVNIs')
plt.ylabel('')
plt.xlabel('')
plt.show()

# Gráfico de barras para la Pregunta 2
plt.figure(figsize=(10, 6))
sns.countplot(x='Pregunta 2: Si fueras un OVNI, ¿de qué tipo serías?', data=df, palette='viridis')
plt.title('Tipo de OVNI Preferido')
plt.xlabel('')
plt.ylabel('')
plt.show()

# Gráfico de barras para la Pregunta 3
plt.figure(figsize=(10, 6))
sns.countplot(x='Pregunta 3: ¿Crees que hay alienígenas en el Área 51?', data=df, palette='viridis')
plt.title('Creencia en Alienígenas en el Área 51')
plt.xlabel('')
plt.ylabel('')
plt.show()

# Gráfico de barras para la Pregunta 5
plt.figure(figsize=(10, 6))
sns.histplot(df['Pregunta 5: ¿Puntúa del 1 al 10 este proyecto?'], kde=True, color='c', bins=10)
plt.title('Puntuación del Proyecto')
plt.xlabel('Puntuación')
plt.ylabel('')
plt.show()

# %%
# Graficamos los resultados de la encuesta
plt.figure(figsize=(10, 6)) 
ax = sns.barplot(x='¿Cómo te llamas?', y='Pregunta 5: ¿Puntúa del 1 al 10 este proyecto?', data=df, palette='magma')
ax.set(xlabel='', ylabel='')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.set_title('Puntuación de la Encuesta', fontsize=24, y=1.1)
plt.show()

# %%
Puntuacion_media = df['Pregunta 5: ¿Puntúa del 1 al 10 este proyecto?'].mean()
print(f"La puntuación media de los alumnos de Upgrade Hub sobre el proyecto de OVNIs ha sido {Puntuacion_media}")
# Out:
# La puntuación media de los alumnos de Upgrade Hub sobre el proyecto de OVNIs ha sido 9.666666666666666
